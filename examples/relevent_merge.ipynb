# %% [markdown]
# # Visual Transformer with Linformer
#
# Training Visual Transformer on *Dogs vs Cats Data*
#
# * Dogs vs. Cats Redux: Kernels Edition - https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition
# * Base Code - https://www.kaggle.com/reukki/pytorch-cnn-tutorial-with-cats-and-dogs/
# * Efficient Attention Implementation - https://github.com/lucidrains/vit-pytorch#efficient-attention

# %%
# !pip -q install vit_pytorch linformer

# %% [markdown]
# ## Import Libraries

# %%
from __future__ import print_function

import glob
from itertools import chain
import os
import random
import zipfile

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from linformer import Linformer
from PIL import Image
from sklearn.model_selection import train_test_split
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms
from tqdm.notebook import tqdm

from vit_pytorch.efficient import ViT
from pathlib import Path

# %%
print(f"Torch: {torch.__version__}")
# Out:
# Torch: 2.1.0+cu118

# %%
# Training settings
batch_size = 64
epochs = 20
lr = 3e-5
gamma = 0.7
seed = 42

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True

seed_everything(seed)

# %%
device = 'cuda'

# %% [markdown]
# ## Load Data

# %%
os.makedirs('data', exist_ok=True)

# %%
dataset_dir =r'C:\xpj\UNIPUS\OCR\ocrdataset\relevant_dataset'
with open(r'C:\xpj\github\vit-pytorch\examples\data\train.txt', 'r') as f:
    train_key = [line.strip() for line in f.readlines()]
with open(r'C:\xpj\github\vit-pytorch\examples\data\val.txt', 'r') as f:
    val_key = [line.strip() for line in f.readlines()]
train_key
val_key
# Out:
# ['329420006_15',
#  '325640012_19_n',
#  '329420003_19_n',
#  '298840001_10_n',
#  '325640018_4_n',
#  '299360001_1_n',
#  '345640001_149',
#  '299410001_8',
#  '325640002_11',
#  '325640017_4_n',
#  '340590001_117_n',
#  '317040001_10_n',
#  '315470002_15',
#  '299380001_4_n',
#  '317040001_20_n',
#  '335530001_188',
#  '298330001_12',
#  '329420006_16_n',
#  '325640012_9_n',
#  '300230001_11',
#  '296840006_1',
#  '325640002_9_n',
#  '173720101_50_n',
#  '325640007_3_n',
#  '173690101_198',
#  '325640014_8',
#  '173740201_64_n',
#  '317040001_27',
#  '345640001_95',
#  '325640003_6',
#  '317000001_14_n',
#  '341940001_5_n',
#  '325640015_8_n',
#  '325640013_19',
#  '329420001_27',
#  '173730201_92',
#  '325640008_22',
#  '173700101_45',
#  '317040001_15_n',
#  '173700101_35_n',
#  '329420003_24_n',
#  '296840004_4_n',
#  '299990001_3_n',
#  '173690101_49_n',
#  '325640015_3_n',
#  '296840001_6',
#  '341490001_4',
#  '325640004_16_n',
#  '325640002_5',
#  '325640007_7',
#  '296840004_8',
#  '173720101_78',
#  '329420003_16_n',
#  '325640001_8_n',
#  '317040001_11',
#  '325640002_19_n',
#  '329420002_12_n',
#  '325640001_3',
#  '299350001_1',
#  '325640006_15_n',
#  '296840001_12',
#  '173730201_114',
#  '345640001_141_n',
#  '295960001_3_n',
#  '325640013_3_n',
#  '299380001_2',
#  '296230001_10_n',
#  '295980001_9_n',
#  '325640012_4_n',
#  '296840006_8_n',
#  '335530001_161_n',
#  '173740201_20',
#  '296380001_14_n',
#  '297150001_12_n',
#  '317040001_5_n',
#  '173730201_16',
#  '315470002_12_n',
#  '325640018_15_n',
#  '173730201_116_n',
#  '329420001_12_n',
#  '341910001_4_n',
#  '284760101_5',
#  '296230001_3',
#  '329420005_8',
#  '284750101_3',
jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/317040001_29.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/317040001_30.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/317040001_4.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/317040001_5.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/317040001_7.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/317040001_8.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/317040001_9.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640001_10.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640001_11.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640001_12.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640001_14.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640001_16.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640001_17.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640001_18.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640001_20.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640001_21.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640001_22.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640001_4.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640001_5.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640001_6.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640001_9.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640002_1.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640002_10.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640002_12.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640002_13.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640002_16.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640002_17.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640002_19.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640002_2.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640002_20.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640002_22.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640002_3.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640002_6.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640002_7.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640002_8.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640003_1.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640003_12.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640003_13.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640003_14.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640003_15.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640003_16.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640003_17.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640003_18.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640003_19.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640003_2.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640003_21.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640003_5.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640003_7.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640003_8.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640004_1.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640004_10.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640004_11.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640004_12.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640004_15.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640004_18.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640004_20.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640004_21.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640004_22.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640004_3.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640004_6.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640004_7.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640004_8.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640004_9.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640005_1.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640005_10.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640005_12.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640005_13.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640005_14.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640005_15.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640005_16.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640005_17.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640005_18.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640005_19.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640005_20.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640005_22.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640005_4.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640005_5.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640005_6.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640005_7.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640005_8.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640005_9.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640006_1.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640006_10.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640006_13.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640006_14.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640006_15.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640006_16.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640006_17.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640006_18.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640006_19.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640006_2.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640006_3.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640006_4.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640006_5.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640006_6.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640006_7.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640006_9.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640007_10.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640007_11.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640007_13.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640007_14.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640007_15.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640007_16.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640007_18.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640007_2.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640007_20.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640007_22.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640007_6.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640007_8.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640007_9.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640008_1.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640008_10.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640008_12.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640008_13.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640008_14.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640008_15.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640008_16.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640008_17.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640008_18.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640008_19.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640008_2.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640008_20.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640008_21.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640008_3.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640008_4.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640008_5.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640008_6.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640008_7.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640008_9.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640009_10.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640009_15.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640009_16.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640009_17.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640009_19.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640009_20.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640009_21.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640009_3.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640009_4.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640009_5.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640009_9.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640010_10.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640010_11.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640010_14.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640010_15.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640010_16.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640010_17.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640010_18.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640010_2.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640010_20.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640010_21.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640010_5.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640010_6.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640010_7.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640010_9.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640011_10.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640011_11.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640011_12.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640011_14.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640011_18.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640011_21.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640011_4.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640011_6.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640011_7.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640011_8.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640011_9.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640012_10.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640012_11.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640012_13.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640012_15.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640012_18.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640012_19.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640012_2.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640012_20.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640012_21.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640012_22.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640012_3.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640012_5.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640012_9.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640013_10.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640013_12.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640013_13.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640013_15.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640013_18.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640013_2.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640013_20.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640013_21.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640013_22.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640013_3.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640013_4.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640013_5.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640013_8.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640013_9.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640014_10.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640014_11.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640014_12.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640014_13.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640014_14.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640014_15.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640014_19.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640014_2.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640014_21.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640014_22.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640014_4.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640014_5.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640014_6.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640014_7.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640015_10.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640015_12.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640015_13.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640015_14.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640015_18.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640015_19.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640015_20.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640015_22.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640015_3.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640015_4.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640015_5.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640015_7.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640015_8.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640015_9.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640016_10.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640016_14.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640016_15.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640016_18.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640016_2.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640016_20.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640016_3.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640016_4.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640016_5.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640016_6.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640016_7.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640016_9.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640017_10.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640017_11.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640017_12.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640017_13.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640017_14.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640017_15.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640017_18.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640017_2.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640017_20.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640017_21.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640017_3.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640017_4.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640017_5.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640017_6.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640017_7.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640018_10.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640018_11.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640018_12.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640018_13.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640018_14.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640018_15.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640018_21.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640018_22.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640018_3.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640018_4.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640018_5.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640018_6.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640018_7.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640018_8.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/325640018_9.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420001_1.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420001_12.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420001_13.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420001_16.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420001_17.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420001_18.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420001_19.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420001_2.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420001_20.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420001_21.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420001_22.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420001_26.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420001_3.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420001_4.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420001_7.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420001_8.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420001_9.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420002_1.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420002_10.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420002_11.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420002_12.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420002_14.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420002_15.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420002_17.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420002_18.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420002_19.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420002_20.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420002_21.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420002_23.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420002_24.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420002_25.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420002_26.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420002_3.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420002_4.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420002_6.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420002_8.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420002_9.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420003_1.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420003_10.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420003_11.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420003_13.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420003_14.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420003_15.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420003_17.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420003_18.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420003_19.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420003_20.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420003_21.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420003_22.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420003_23.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420003_24.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420003_26.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420003_3.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420003_4.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420003_5.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420003_6.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420003_8.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420004_1.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420004_11.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420004_13.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420004_17.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420004_18.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420004_19.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420004_2.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420004_22.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420004_25.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420004_26.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420004_3.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420004_4.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420004_6.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420004_7.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420004_9.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420005_12.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420005_13.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420005_14.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420005_15.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420005_16.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420005_17.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420005_18.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420005_2.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420005_20.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420005_22.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420005_5.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420005_7.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420005_9.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420006_1.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420006_11.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420006_14.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420006_16.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420006_17.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420006_2.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420006_20.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420006_22.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420006_23.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420006_3.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420006_4.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420006_6.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420006_7.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420006_8.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/329420006_9.jpg'),
#  WindowsPath('C:/xpj/UNIPUS/OCR/ocrdataset/relevant_dataset/1/341910001_3.jpg')]

# %%
print(f"Train Data: {len(train_list)}")
print(f"Test Data: {len(valid_list)}")
# Out:
# Train Data: 568
# Test Data: 256

# %%
# labels = [path.split('/')[-1].split('.')[0] for path in train_list]

# %% [markdown]
# ## Random Plots

# %%
random_idx = np.random.randint(1, len(train_list), size=9)
fig, axes = plt.subplots(3, 3, figsize=(16, 12))

for idx, ax in enumerate(axes.ravel()):
    img = Image.open(train_list[idx])
    # ax.set_title(labels[idx])
    ax.imshow(img)

# %% [markdown]
# ## Split

# %%
# train_list, valid_list = train_test_split(train_list, 
#                                           test_size=0.2,
#                                           stratify=labels,
#                                           random_state=seed)

# %%
print(f"Train Data: {len(train_list)}")
print(f"Validation Data: {len(valid_list)}")
# print(f"Test Data: {len(test_list)}")
# Out:
# Train Data: 568
# Validation Data: 256

# %% [markdown]
# ## Image Augmentation

# %%
train_transforms = transforms.Compose(
    [
        transforms.Resize((224, 224)),
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
    ]
)

val_transforms = transforms.Compose(
    [
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
    ]
)


test_transforms = transforms.Compose(
    [
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
    ]
)

# %% [markdown]
# ## Load Datasets

# %%
class CatsDogsDataset(Dataset):
    def __init__(self, file_list, transform=None):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        self.filelength = len(self.file_list)
        return self.filelength

    def __getitem__(self, idx):
        img_path = self.file_list[idx]
        folder =img_path.parent
        base_name =img_path.stem
        pair_base_name = base_name+'_pdf'+'.jpg'
        img_pair_path = os.path.join(folder, pair_base_name)
        img = Image.open(img_path)
        img_pair = Image.open(img_pair_path)
        
        img_merge = Image.new('RGB', (img.width + img_pair.width, img.height))
        img_merge.paste(img, (0, 0))
        img_merge.paste(img_pair, (img.width, 0))
        if self.transform:
            img_merge = self.transform(img_merge)

        # img_transformed = self.transform(img)
        # img_pair_transformed = self.transform(img_pair)
        # if img_transformed.shape[0] == 1:
        #     img_transformed = img_transformed.expand(3, -1, -1)
        # if img_pair_transformed.shape[0] == 1:
        #     img_pair_transformed = img_pair_transformed.expand(3, -1, -1)
        # img_transformed_expand = img_transformed.unsqueeze(0)
        # img_pair_transformed_expand = img_pair_transformed.unsqueeze(0)
        # img_merge = torch.cat((img_transformed_expand,img_pair_transformed_expand),0)
        label = int(str(folder).split("\\")[-1])
        # label = img_path.split("/")[-1].split(".")[0]
        # label = 1 if label == "dog" else 0

        return img_merge, label

# %%
train_data = CatsDogsDataset(train_list, transform=train_transforms)
valid_data = CatsDogsDataset(valid_list, transform=test_transforms)
# test_data = CatsDogsDataset(test_list, transform=test_transforms)

# %%
train_loader = DataLoader(dataset = train_data, batch_size=batch_size, shuffle=True )
valid_loader = DataLoader(dataset = valid_data, batch_size=batch_size, shuffle=True)
# test_loader = DataLoader(dataset = test_data, batch_size=batch_size, shuffle=True)

# %%
print(len(train_data), len(train_loader))
# Out:
# 568 9

# %%
print(len(valid_data), len(valid_loader))
# Out:
# 256 4

# %% [markdown]
# ## Efficient Attention

# %% [markdown]
# ### Linformer

# %%
efficient_transformer = Linformer(
    dim=128,
    seq_len=49+1,  # 7x7 patches + 1 cls-token
    depth=12,
    heads=8,
    k=64
)

# %% [markdown]
# ### Visual Transformer

# %%
model = ViT(
    dim=128,
    image_size=224,
    patch_size=32,
    num_classes=128,
    transformer=efficient_transformer,
    channels=3,
).to(device)

# %% [markdown]
# ### Training

# %%
# loss function
criterion = nn.CrossEntropyLoss()
# optimizer
optimizer = optim.Adam(model.parameters(), lr=lr)
# scheduler
scheduler = StepLR(optimizer, step_size=1, gamma=gamma)

# %%
from torch.nn import Linear
fc = Linear(256,128,bias=True).to(device)
fc2 = Linear(128,2,bias=True).to(device)
for epoch in range(epochs):
    epoch_loss = 0
    epoch_accuracy = 0

    for data, label in tqdm(train_loader):
        data = data.to(device) #B 2 3 224 224
        label = label.to(device)

        output = model(data)
        # data_0 =data[:,0]
        # data_1 =data[:,1]
        # output_0 = model(data_0)
        # output_1 = model(data_1)
        # output_cat = torch.cat((output_0,output_1),1)
        # output_linear = fc(output_cat)
        # output = fc2(output_linear)
        # output = model(data)
        loss = criterion(output, label)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        acc = (output.argmax(dim=1) == label).float().mean()
        epoch_accuracy += acc / len(train_loader)
        epoch_loss += loss / len(train_loader)

    with torch.no_grad():
        epoch_val_accuracy = 0
        epoch_val_loss = 0
        for data, label in valid_loader:
            data = data.to(device)
            label = label.to(device)

            val_output = model(data)
            # data_0 =data[:,0]
            # data_1 =data[:,1]
            # output_0 = model(data_0)
            # output_1 = model(data_1)
            # output_cat = torch.cat((output_0,output_1),1)
            # val_output_linear = fc(output_cat)
            # val_output = fc2(val_output_linear)

            # val_output = model(data)
            val_loss = criterion(val_output, label)

            acc = (val_output.argmax(dim=1) == label).float().mean()
            epoch_val_accuracy += acc / len(valid_loader)
            epoch_val_loss += val_loss / len(valid_loader)

    print(
        f"Epoch : {epoch+1} - loss : {epoch_loss:.4f} - acc: {epoch_accuracy:.4f} - val_loss : {epoch_val_loss:.4f} - val_acc: {epoch_val_accuracy:.4f}\n"
    )
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# Epoch : 1 - loss : 4.3323 - acc: 0.2378 - val_loss : 3.0676 - val_acc: 1.0000
#   0%|          | 0/9 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 8
#       5 epoch_loss = 0
#       6 epoch_accuracy = 0
# ----> 8 for data, label in tqdm(train_loader):
#       9     data = data.to(device) #B 2 3 224 224
#      10     label = label.to(device)
#
# File c:\Users\20142\.conda\envs\clip\lib\site-packages\tqdm\notebook.py:249, in tqdm_notebook.__iter__(self)
#     247 try:
#     248     it = super(tqdm_notebook, self).__iter__()
# --> 249     for obj in it:
#     250         # return super(tqdm...) will not catch exception
#     251         yield obj
#     252 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#
# File c:\Users\20142\.conda\envs\clip\lib\site-packages\tqdm\std.py:1182, in tqdm.__iter__(self)
#    1179 time = self._time
#    1181 try:
# -> 1182     for obj in iterable:
#    1183         yield obj
#    1184         # Update and possibly print the progressbar.
#    1185         # Note: does not call self.update(1) for speed optimisation.
#
# File c:\Users\20142\.conda\envs\clip\lib\site-packages\torch\utils\data\dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File c:\Users\20142\.conda\envs\clip\lib\site-packages\torch\utils\data\dataloader.py:674, in _SingleProcessDataLoaderIter._next_data(self)
#     672 def _next_data(self):
#     673     index = self._next_index()  # may raise StopIteration
# --> 674     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675     if self._pin_memory:
#     676         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\20142\.conda\envs\clip\lib\site-packages\torch\utils\data\_utils\fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File c:\Users\20142\.conda\envs\clip\lib\site-packages\torch\utils\data\_utils\fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# Cell In[14], line 20, in CatsDogsDataset.__getitem__(self, idx)
#      17 img_pair = Image.open(img_pair_path)
#      19 img_merge = Image.new('RGB', (img.width + img_pair.width, img.height))
# ---> 20 img_merge.paste(img, (0, 0))
#      21 img_merge.paste(img_pair, (img.width, 0))
#      22 if self.transform:
#
# File c:\Users\20142\.conda\envs\clip\lib\site-packages\PIL\Image.py:1727, in Image.paste(self, im, box, mask)
#    1724     im = ImageColor.getcolor(im, self.mode)
#    1726 elif isImageType(im):
# -> 1727     im.load()
#    1728     if self.mode != im.mode:
#    1729         if self.mode != "RGB" or im.mode not in ("LA", "RGBA", "RGBa"):
#    1730             # should use an adapter for this!
#
# File c:\Users\20142\.conda\envs\clip\lib\site-packages\PIL\ImageFile.py:269, in ImageFile.load(self)
#     266         raise OSError(msg)
#     268 b = b + s
# --> 269 n, err_code = decoder.decode(b)
#     270 if n < 0:
#     271     break
#
# KeyboardInterrupt:

# %%
torch.save(model.state_dict(), 'vit_model.pth')
